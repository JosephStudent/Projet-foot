# %%
#Importation Librairie
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importation des données
joeurs = pd.read_csv('all_players.csv', sep=',')
j_Masculin = pd.read_csv('male_players.csv', sep=',')
j_Feminin = pd.read_csv('female_players.csv', sep=',')
#Afichage des première ligne des données
print(f"Données de tout les joueurs : ")
display(joeurs.head())
print(f"Données des joeurs Masculins: ")
display(j_Masculin.head())
print("Données des joeurs Feminin:")
display(j_Feminin.head())
# Out:
# Données de tout les joueurs :
#    Unnamed: 0.1  Unnamed: 0  Rank             Name  OVR  PAC  SHO  PAS  DRI  \
# 0             0           0     1    Kylian Mbappé   91   97   90   80   92
# 1             1           1     2            Rodri   91   66   80   86   84
# 2             2           2     4   Erling Haaland   91   88   92   70   81
# 3             3           3     5  Jude Bellingham   90   80   87   83   88
# 4             4           4     7         Vini Jr.   90   95   84   81   91
#
#    DEF  ...   Nation            League             Team  \
# 0   36  ...   France  LALIGA EA SPORTS      Real Madrid
# 1   87  ...    Spain    Premier League  Manchester City
# 2   45  ...   Norway    Premier League  Manchester City
# 3   78  ...  England  LALIGA EA SPORTS      Real Madrid
# 4   29  ...   Brazil  LALIGA EA SPORTS      Real Madrid
#
#                                           play style  \
# 0  Quick Step+, Acrobatic, Finesse Shot, Flair, R...
# 1  Tiki Taka+, Aerial, Bruiser, Long Ball Pass, P...
# 2  Acrobatic+, Bruiser, Power Header, Power Shot,...
# 3  Relentless+, Flair, Intercept, Slide Tackle, T...
# 4  Quick Step+, Chip Shot, Finesse Shot, First To...
#
#                                                  url  GK Diving  GK Handling  \
# 0  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 1  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 2  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 3  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 4  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
#
#    GK Kicking  GK Positioning  GK Reflexes
# 0         NaN             NaN          NaN
# 1         NaN             NaN          NaN
# 2         NaN             NaN          NaN
# 3         NaN             NaN          NaN
# 4         NaN             NaN          NaN
#
# [5 rows x 58 columns]
# Données des joeurs Masculins:
#    Unnamed: 0.1  Unnamed: 0  Rank             Name  OVR  PAC  SHO  PAS  DRI  \
# 0             0           0     1    Kylian Mbappé   91   97   90   80   92
# 1             1           1     2            Rodri   91   66   80   86   84
# 2             2           2     4   Erling Haaland   91   88   92   70   81
# 3             3           3     5  Jude Bellingham   90   80   87   83   88
# 4             4           4     7         Vini Jr.   90   95   84   81   91
#
#    DEF  ...   Nation            League             Team  \
# 0   36  ...   France  LALIGA EA SPORTS      Real Madrid
# 1   87  ...    Spain    Premier League  Manchester City
# 2   45  ...   Norway    Premier League  Manchester City
# 3   78  ...  England  LALIGA EA SPORTS      Real Madrid
# 4   29  ...   Brazil  LALIGA EA SPORTS      Real Madrid
#
#                                           play style  \
# 0  Quick Step+, Acrobatic, Finesse Shot, Flair, R...
# 1  Tiki Taka+, Aerial, Bruiser, Long Ball Pass, P...
# 2  Acrobatic+, Bruiser, Power Header, Power Shot,...
# 3  Relentless+, Flair, Intercept, Slide Tackle, T...
# 4  Quick Step+, Chip Shot, Finesse Shot, First To...
#
#                                                  url  GK Diving  GK Handling  \
# 0  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 1  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 2  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 3  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 4  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
#
#    GK Kicking  GK Positioning  GK Reflexes
# 0         NaN             NaN          NaN
# 1         NaN             NaN          NaN
# 2         NaN             NaN          NaN
# 3         NaN             NaN          NaN
# 4         NaN             NaN          NaN
#
# [5 rows x 58 columns]
# Données des joeurs Feminin:
#    Unnamed: 0.1  Unnamed: 0  Rank                    Name  OVR  PAC  SHO  PAS  \
# 0             0           0     3          Aitana Bonmatí   91   81   86   86
# 1             1           1     6         Alexia Putellas   90   82   89   90
# 2             2           2     8  Caroline Graham Hansen   90   89   87   88
# 3             3           3    10                Sam Kerr   90   85   88   74
# 4             4           4    14            Sophia Smith   89   93   86   79
#
#    DRI  DEF  ...         Nation        League             Team  \
# 0   91   77  ...          Spain        Liga F     FC Barcelona
# 1   91   72  ...          Spain        Liga F     FC Barcelona
# 2   90   47  ...         Norway        Liga F     FC Barcelona
# 3   90   42  ...      Australia  Barclays WSL          Chelsea
# 4   89   45  ...  United States          NWSL  Portland Thorns
#
#                                           play style  \
# 0  Technical+, Finesse Shot, First Touch, Incisiv...
# 1  First Touch+, Finesse Shot, Flair, Incisive Pa...
# 2  Trickster+, Finesse Shot, First Touch, Flair, ...
# 3  Finesse Shot+, Acrobatic, Aerial, Power Header...
# 4  First Touch+, Finesse Shot, Flair, Quick Step,...
#
#                                                  url  GK Diving  GK Handling  \
# 0  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 1  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 2  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 3  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
# 4  https://www.ea.com/games/ea-sports-fc/ratings/...        NaN          NaN
#
#    GK Kicking  GK Positioning  GK Reflexes
# 0         NaN             NaN          NaN
# 1         NaN             NaN          NaN
# 2         NaN             NaN          NaN
# 3         NaN             NaN          NaN
# 4         NaN             NaN          NaN
#
# [5 rows x 58 columns]

# %% [markdown]
# j'ai utilisé display pour une meilleur lecture des données que cela me les separes

# %%
# Affichage des noms des colonnes pour chaque DataFrame
print("Colonnes des joueurs (tous) :", joeurs.columns)
print("Colonnes des joueurs masculins :", j_Masculin.columns)
print("Colonnes des joueurs féminins :", j_Feminin.columns)
# Out:
# Colonnes des joueurs (tous) : Index(['Unnamed: 0.1', 'Unnamed: 0', 'Rank', 'Name', 'OVR', 'PAC', 'SHO',
#        'PAS', 'DRI', 'DEF', 'PHY', 'Acceleration', 'Sprint Speed',
#        'Positioning', 'Finishing', 'Shot Power', 'Long Shots', 'Volleys',
#        'Penalties', 'Vision', 'Crossing', 'Free Kick Accuracy',
#        'Short Passing', 'Long Passing', 'Curve', 'Dribbling', 'Agility',
#        'Balance', 'Reactions', 'Ball Control', 'Composure', 'Interceptions',
#        'Heading Accuracy', 'Def Awareness', 'Standing Tackle',
#        'Sliding Tackle', 'Jumping', 'Stamina', 'Strength', 'Aggression',
#        'Position', 'Weak foot', 'Skill moves', 'Preferred foot', 'Height',
#        'Weight', 'Alternative positions', 'Age', 'Nation', 'League', 'Team',
#        'play style', 'url', 'GK Diving', 'GK Handling', 'GK Kicking',
#        'GK Positioning', 'GK Reflexes'],
#       dtype='object')
# Colonnes des joueurs masculins : Index(['Unnamed: 0.1', 'Unnamed: 0', 'Rank', 'Name', 'OVR', 'PAC', 'SHO',
#        'PAS', 'DRI', 'DEF', 'PHY', 'Acceleration', 'Sprint Speed',
#        'Positioning', 'Finishing', 'Shot Power', 'Long Shots', 'Volleys',
#        'Penalties', 'Vision', 'Crossing', 'Free Kick Accuracy',
#        'Short Passing', 'Long Passing', 'Curve', 'Dribbling', 'Agility',
#        'Balance', 'Reactions', 'Ball Control', 'Composure', 'Interceptions',
#        'Heading Accuracy', 'Def Awareness', 'Standing Tackle',
#        'Sliding Tackle', 'Jumping', 'Stamina', 'Strength', 'Aggression',
#        'Position', 'Weak foot', 'Skill moves', 'Preferred foot', 'Height',
#        'Weight', 'Alternative positions', 'Age', 'Nation', 'League', 'Team',
#        'play style', 'url', 'GK Diving', 'GK Handling', 'GK Kicking',
#        'GK Positioning', 'GK Reflexes'],
#       dtype='object')
# Colonnes des joueurs féminins : Index(['Unnamed: 0.1', 'Unnamed: 0', 'Rank', 'Name', 'OVR', 'PAC', 'SHO',
#        'PAS', 'DRI', 'DEF', 'PHY', 'Acceleration', 'Sprint Speed',
#        'Positioning', 'Finishing', 'Shot Power', 'Long Shots', 'Volleys',
#        'Penalties', 'Vision', 'Crossing', 'Free Kick Accuracy',
#        'Short Passing', 'Long Passing', 'Curve', 'Dribbling', 'Agility',
#        'Balance', 'Reactions', 'Ball Control', 'Composure', 'Interceptions',
#        'Heading Accuracy', 'Def Awareness', 'Standing Tackle',
#        'Sliding Tackle', 'Jumping', 'Stamina', 'Strength', 'Aggression',
#        'Position', 'Weak foot', 'Skill moves', 'Preferred foot', 'Height',
#        'Weight', 'Alternative positions', 'Age', 'Nation', 'League', 'Team',
#        'play style', 'url', 'GK Diving', 'GK Handling', 'GK Kicking',
#        'GK Positioning', 'GK Reflexes'],
#       dtype='object')

# %%
# Out:
# Valeurs manquantes pour GK:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Vérifier les valeurs manquantes pour chaque attribut par poste
#       2 print("Valeurs manquantes pour GK:")
# ----> 3 print(j_Masculin[positions_attributes['GK']].isna().sum())
#       5 print("Valeurs manquantes pour DF:")
#       6 print(j_Masculin[positions_attributes['DF']].isna().sum())
#
# NameError: name 'positions_attributes' is not defined

# %% [markdown]
# ## Analyse des statistiques des joueurs
# En se basant sur les carte Stat FIFA.
# je vais regrouper les données soudjascente entre elle et faire une moyenne ponderé.
#
# PAC (Pace) : Moyenne de 'Acceleration' et 'Sprint Speed'
# SHO (Shooting) : Moyenne de 'Finishing', 'Shot Power', 'Long Shots', 'Volleys', 'Penalties'
# PAS (Passing) : Moyenne de 'Vision', 'Crossing', 'Free Kick Accuracy', 'Short Passing', 'Long Passing', 'Curve'
# DRI (Dribbling) : Moyenne de 'Dribbling', 'Agility', 'Balance', 'Ball Control'
# DEF (Defense) : Moyenne de 'Interceptions', 'Heading Accuracy', 'Def Awareness', 'Standing Tackle', 'Sliding Tackle'
# PHY (Physical) : Moyenne de 'Jumping', 'Stamina', 'Strength', 'Aggression'

# %%
# Définir les catégories et les attributs correspondants
categories = {
    'PAC': ['Acceleration', 'Sprint Speed'],
    'SHO': ['Finishing', 'Shot Power', 'Long Shots', 'Volleys', 'Penalties'],
    'PAS': ['PAS','Vision', 'Crossing', 'Free Kick Accuracy', 'Short Passing', 'Long Passing', 'Curve'],
    'DRI': ['DRI','Dribbling', 'Agility', 'Balance', 'Ball Control'],
    'DEF': ['DEF','Interceptions', 'Heading Accuracy', 'Def Awareness', 'Standing Tackle', 'Sliding Tackle'],
    'PHY': ['PHY', 'Jumping', 'Stamina', 'Strength', 'Aggression']
}

# Fonction pour calculer les moyennes par catégorie
def calculate_means(df, categories):
    for category, attrs in categories.items():
        df[category] = df[attrs].mean(axis=1)
    return df

# Appliquer la fonction aux DataFrames
j_Masculin = calculate_means(j_Masculin, categories)
j_Feminin = calculate_means(j_Feminin, categories)

# Afficher les statistiques résumées pour les joueurs masculins et féminins
print("Données des joueurs Masculins :")
display(j_Masculin[['Name', 'Position', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY']].head())

print("Données des joueurs Féminins :")
display(j_Feminin[['Name', 'Position', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY']].head())
# Out:
# Données des joueurs Masculins :
#               Name Position   PAC   SHO        PAS   DRI        DEF   PHY
# 0    Kylian Mbappé       ST  97.0  87.0  78.142857  90.4  39.833333  79.0
# 1            Rodri      CDM  65.5  77.6  82.857143  78.2  85.500000  85.4
# 2   Erling Haaland       ST  87.0  90.6  69.142857  77.8  47.500000  87.4
# 3  Jude Bellingham      CAM  80.5  82.4  79.714286  85.4  78.000000  84.4
# 4         Vini Jr.       LW  95.0  79.4  78.285714  90.4  30.000000  70.0
# Données des joueurs Féminins :
#                      Name Position   PAC   SHO        PAS   DRI        DEF  \
# 0          Aitana Bonmatí       CM  81.0  79.8  83.714286  90.6  73.666667
# 1         Alexia Putellas       CM  81.5  89.0  89.714286  90.4  71.500000
# 2  Caroline Graham Hansen       RW  89.0  85.0  87.000000  88.4  49.000000
# 3                Sam Kerr       ST  85.0  85.0  73.142857  88.6  45.333333
# 4            Sophia Smith       ST  92.5  83.8  76.428571  88.0  48.166667
#
#     PHY
# 0  74.2
# 1  79.0
# 2  77.4
# 3  83.0
# 4  84.4

# %% [markdown]
# Pour me permettre de faire une permière selection des joueurs je vais me baser sur la positions des joueur sur le terrain et leur attribut donc je vais  selectionner les attribut que j'ai juger pertinent pour mon analyse dans la selection des joueur. les attributs pertinents  (PAC, SHO,Positionning, etc.) pour chaque joueur, selon leur position sur le terrain (gardien, défenseur, milieu, attaquant)

# %%
# Sélection des attributs pertinents pour l'analyse
colonnes_pertinentes = ['Name', 'Position', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Positioning','Reactions',  'Composure', 'Preferred foot', 'Height',  'Weight', 'Alternative positions', ]

# Affichage des statistiques pour les joueurs masculins et féminins
print("Stats pertinentes des joueurs Masculin:")
display(j_Masculin[colonnes_pertinentes].head())

print("Stats pertinentes des joueurs Féminin:")
display(j_Feminin[colonnes_pertinentes].head())
# Out:
# Stats pertinentes des joueurs Masculin:
#               Name Position   PAC   SHO        PAS   DRI        DEF   PHY  \
# 0    Kylian Mbappé       ST  97.0  87.0  78.142857  90.4  39.833333  79.0
# 1            Rodri      CDM  65.5  77.6  82.857143  78.2  85.500000  85.4
# 2   Erling Haaland       ST  87.0  90.6  69.142857  77.8  47.500000  87.4
# 3  Jude Bellingham      CAM  80.5  82.4  79.714286  85.4  78.000000  84.4
# 4         Vini Jr.       LW  95.0  79.4  78.285714  90.4  30.000000  70.0
#
#    Positioning  Reactions  Composure Preferred foot        Height  \
# 0           93         93         88          Right  182cm / 6'0"
# 1           76         93         94          Right  191cm / 6'3"
# 2           96         94         87           Left  195cm / 6'5"
# 3           91         91         87          Right  186cm / 6'1"
# 4           87         86         83          Right  176cm / 5'9"
#
#          Weight Alternative positions
# 0  75kg / 165lb                    LW
# 1  82kg / 181lb                    CM
# 2  94kg / 207lb                   NaN
# 3  75kg / 165lb                    CM
# 4  73kg / 161lb                ST, LM
# Stats pertinentes des joueurs Féminin:
#                      Name Position   PAC   SHO        PAS   DRI        DEF  \
# 0          Aitana Bonmatí       CM  81.0  79.8  83.714286  90.6  73.666667
# 1         Alexia Putellas       CM  81.5  89.0  89.714286  90.4  71.500000
# 2  Caroline Graham Hansen       RW  89.0  85.0  87.000000  88.4  49.000000
# 3                Sam Kerr       ST  85.0  85.0  73.142857  88.6  45.333333
# 4            Sophia Smith       ST  92.5  83.8  76.428571  88.0  48.166667
#
#     PHY  Positioning  Reactions  Composure Preferred foot        Height  \
# 0  74.2           91         91         85          Right  162cm / 5'4"
# 1  79.0           91         90         92           Left  173cm / 5'8"
# 2  77.4           87         83         84          Right  175cm / 5'9"
# 3  83.0           92         89         91          Right  168cm / 5'6"
# 4  84.4           89         89         80          Right  164cm / 5'5"
#
#          Weight Alternative positions
# 0  53kg / 117lb                   CAM
# 1  69kg / 152lb                   CAM
# 2  59kg / 130lb                    RM
# 3  66kg / 146lb                   NaN
# 4  58kg / 128lb                    RW

# %% [markdown]
# ## Visualisation des performances par position
# Cela nous permettra d'identifier les meilleurs joueurs pour chaque rôle.

# %%
# Assure-toi que les colonnes utilisées pour l'agrégation sont numériques
cols_to_use = ['PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Positioning', 'Reactions']
j_masculin[cols_to_use] = j_masculin[cols_to_use].apply(pd.to_numeric, errors='coerce')

# Remplir les valeurs manquantes
j_masculin.fillna(j_masculin.mean(), inplace=True)

# Regrouper les données par position et calculer la moyenne
positions_data = j_masculin.groupby('Position')[cols_to_use].mean().reset_index()

# Créer les graphiques
plt.figure(figsize=(14, 10))
for i, category in enumerate(cols_to_use, start=1):
    plt.subplot(3, 3, i)
    sns.barplot(x='Position', y=category, data=positions_data)
    plt.title(f'Average {category} by Position')
    plt.ylabel('Average Score')
    plt.xlabel('Position')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Préparer les données par position
positions_data = j_Masculin.groupby('Position')[['PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Positioning','Reactions',  'Composure']].mean().reset_index()

# Créer les graphiques
plt.figure(figsize=(14, 10))
for i, category in enumerate(['PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Positioning','Reactions',  'Composure'], start=1):
    plt.subplot(3, 2, i)
    sns.barplot(x='Position', y=category, data=positions_data)
    plt.title(f'Average {category} by Position')
    plt.ylabel('Average Score')
    plt.xlabel('Position')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 7
#       5 plt.figure(figsize=(14, 10))
#       6 for i, category in enumerate(['PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Positioning','Reactions',  'Composure'], start=1):
# ----> 7     plt.subplot(3, 2, i)
#       8     sns.barplot(x='Position', y=category, data=positions_data)
#       9     plt.title(f'Average {category} by Position')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# -> 1440 key = SubplotSpec._from_subplot_args(fig, args)
#    1442 for ax in fig.axes:
#    1443     # If we found an Axes at the position, we can re-use it if the user passed no
#    1444     # kwargs or if the axes class and kwargs are identical.
#    1445     if (ax.get_subplotspec() == key
#    1446         and (kwargs == {}
#    1447              or (ax._projection_init
#    1448                  == fig._process_projection_requirements(**kwargs)))):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\gridspec.py:599, in SubplotSpec._from_subplot_args(figure, args)
#     597 else:
#     598     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 599         raise ValueError(
#     600             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     601             f"not {num!r}"
#     602         )
#     603     i = j = num
#     604 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 6, not 7

# %% [markdown]
# ## Visualisation des attribut par rapport au position
# pour voir les quel sont les plus haut afin de pouvoir selectionner les attribut pertinent pour chaque poste

# %%
# Visualisation des joueurs par position
plt.figure(figsize=(10, 6))
sns.boxplot(x='Position', y='Sprint Speed', data=j_Masculin)
plt.title('Distribution of Speed by Position (Male Players)')
plt.show()

plt.figure(figsize=(10, 6))
sns.boxplot(x='Position', y='Sprint Speed', data=j_Feminin)
plt.title('Distribution of Speed by Position (Female Players)')
plt.show()
